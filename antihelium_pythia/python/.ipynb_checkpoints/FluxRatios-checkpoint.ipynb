# %%
import numpy as np
from scipy.optimize import brentq
from scipy.interpolate import interp1d
from scipy.integrate import quad
import itertools
from math import factorial

# %% [markdown]
# Todo
# * What is the lower bound on $T$ for antihelium that I should use in the acceptance?

# %%
intMethod3Hebar = "MethodAnn"
phiFVal = 1.5

# %%
dataDir = "../data/"

masses = [100, 1000]
colors = {100: "goldenrod", 1000: "steelblue"}

channels = ["bbbar", "W+W-"]

finalStates = ["pbar", "Dbar", "3Hebar"]
lines = {"pbar": "-", "Dbar": ":", "3Hebar": "--"}

# %%
mp = 0.93827 # proton mass in GeV 
mn = 0.93957 # neutron mass in GeV
mD = 1.8756 # deuterium mass in GeV
m3He = 2.8094 # helium mass in GeV
m3H = 2.8094 # tritium mass in GeV

# %%
def plotBinErrs(binl, binr, val, err, fmt):
    """
    Plots binned data with error bars in the form of little boxes!
    """
    for bl, br, l, u in zip(binl, binr, val-err, val+err):
        plt.fill_between([bl, br], [l, l], [u, u], color=fmt, alpha=1.0, lw=0.75)

# %%
def rigToT(rig, A, absZ, mN):
    """
    Convert rigidity (GV) to kinetic energy per nucleon (GeV/n)
    """
    return (np.sqrt(absZ**2 * rig**2 + mN**2) - mN) / float(A)

# %%
def rigDataToTData(data, A, absZ, mN):
    """
    Given an array with columns
        Rigidity (GV), bin left (GV), bin right (GV), flux ((m^2 sr s GV)^-1),
    constructs corresponding bins as a function of kinetic energy per nucleon (GeV/n) and flux in units of (m^2 sr s GeV/n)^-1. Also returns rescaled total error.
    """
    deltaR = data[:, 2] - data[:, 1]
    binr = rigToT(data[:, 2], A, absZ, mN)
    binl = rigToT(data[:, 1], A, absZ, mN)
    deltaT = binr - binl
    
    # Convert bin centers, rescale flux, sum and rescale errors
    return rigToT(data[:, 0], A, absZ, mN), data[:, 3] * np.divide(deltaR, deltaT), np.sqrt(data[:, 4]**2 + data[:, 5]**2) * np.divide(deltaR, deltaT), binl, binr

# %% [markdown]
# AMS-02 (very rough) estimate of $\bar{p}$ acceptance (arXiv:hep-ph/990448)

# %%
accpbarEst = lambda T: 2.2e7/(1e8*(2.84-0.1)) * (T >= 0.1) * (T <= 2.84)

# %% [markdown]
# AMS-02 $\bar{D}$ acceptance

# %%
# Load AMS-02's Dbar acceptance curve
accDbarData = np.loadtxt(dataDir + "ams_Dbar_acceptance.csv")
accDbarData[:, 0] = rigToT(accDbarData[:, 0], 2, 1, mD)
# Acceptance in m^2 sr as a function of kinetic energy per nucleon in GeV/n
accDbar = interp1d(accDbarData[:, 0], accDbarData[:, 1], kind="linear", bounds_error=False, fill_value=0.0)

# %%
# Alternative estimate from arXiv:hep-ph/990448
accDbarEst = lambda T: 5.5e7/(1e8*(2.84-0.1)) * (T >= 0.1) * (T <= 2.84)

# %% [markdown]
# AMS-02 $\bar{^3{\rm He}}$ acceptance
# ...Converting sensitivity gives an answer that makes no sense: it is larger than AMS-02's geometrical acceptance...

# %%
# TODO: this is just the geometric acceptance... figure out a better estimate...
# Lower bound comes from lowest rigidity bin in He search
accHe = lambda T: 0.5 * (T >= rigToT(2.0, 3, 2, m3He)) # m^2 sr

# %% [markdown]
# AMS-02 antihelium flux sensitivity

# %%
amsHeFluxData = np.loadtxt(dataDir + "ams_He_flux.csv") # only load rigidity, flux
amsHeBins, amsHeFluxes, amsHeFluxErrs, _, _ = rigDataToTData(amsHeFluxData, 3, 2, m3He)
amsHeInterp = interp1d(amsHeBins, amsHeFluxes, kind="linear", bounds_error=False, fill_value=0.0)

# Load 18-year sensitivity
amsHebarHeSensData = np.loadtxt(dataDir + "ams_antiHe_He_18yr_sensitivity.csv")
# Convert rigidity to kinetic energy per nucleon
amsHebarHeSensData[:, 0] = rigToT(amsHebarHeSensData[:, 0], 3, 2, m3He)
# Interpolate the sensitivity
amsHebarHeSens = interp1d(amsHebarHeSensData[:, 0], amsHebarHeSensData[:, 1], kind="linear", bounds_error=False, fill_value=0.0)

# Now convert 18-year antiHe / He ratio to 5-year antiHe flux sensitivity
amsHebarSens = lambda T: amsHeInterp(T) * amsHebarHeSens(T) * 5.0 / 18.0

# %% [markdown]
# AMS-02 antiproton flux

# %%
amspbarFluxData = np.loadtxt(dataDir + "ams_pbar_flux.csv")
amspbarBins, amspbarFluxes, amspbarFluxErrs, amspbarBinl, amspbarBinr = rigDataToTData(amspbarFluxData, 1, 1, mp)

# %% [markdown]
# Another estimate of the antiproton acceptance: divide event counts from $\bar{p}$ paper by flux, observation time and bin width

# %%
deltaTpbar = amspbarBinr - amspbarBinl # bin widths in kinetic energy per nucleon
accpbar = np.divide(amspbarFluxData[:, 6], 3.15e7*4.0 * deltaTpbar * amspbarFluxes) # 4 YEARS OF DATA!!!
accpbar = interp1d(amspbarBins, accpbarPrecise, kind="linear", bounds_error=False, fill_value=0.0)

# %% [markdown]
# Optimistic values for AMS-02's geomagnetic cutoff efficiency

# %%
amsGeoEffData = np.loadtxt(dataDir + "ams_geomagnetic_cutoff_eff.csv")
amsGeoEffpbar = interp1d(rigToT(amsGeoEffData[:, 0], 1, 1, mp), amsGeoEffData[:, 1] * 0.01, bounds_error=False, fill_value=0.0)
amsGeoEffDbar = interp1d(rigToT(amsGeoEffData[:, 0], 2, 1, mD), amsGeoEffData[:, 1] * 0.01, bounds_error=False, fill_value=0.0)
amsGeoEff3Hebar = interp1d(rigToT(amsGeoEffData[:, 0], 3, 2, m3He), amsGeoEffData[:, 1] * 0.01, bounds_error=False, fill_value=0.0)

# %% [markdown]
# BESS upper limit on $\bar{D}$ flux

# %%
bessDbarLim = 1.9e-4 # (m^2 s sr Gev/n)^-1
bessDbarTs = [0.17, 1.15]

# %% [markdown]
# AMS-02 estimated sensitivity to $\bar{D}$

# %%
amsDbarEstLowLim = 2.06e-6 # (m^2 s sr GeV/n)^-1
amsDbarTsLow = [0.179, 0.73] # low region, GeV/n
amsDbarEstHigh1Lim = 1.028e-6
amsDbarTsHigh1 = [2.43, 3.71] # high region 1, GeV/n
amsDbarEstHigh2Lim = 1.94e-6
amsDbarTsHigh2 = [3.71, 4.65] # high region, GeV/n

# %% [markdown]
# GAPS sensitivities

# %%
gapsDbarEstLim = 2.0e-6 # need to divide to convert to (GeV/n)^-1!
gapsDbarTs = [0.1, 0.259]
gaps3HebarEstLim = 1.5e-9 / 3.0 # need to divide to convert to (GeV/n)^-1!
gaps3HebarTs = [0.1, 0.4]

# %%
def nucParams(species):
    """
    Returns mass, mass number (A) and proton number (Z) for the provided species.
    
    Arguments
    -species: "pbar", "Dbar", "3Hebar", "3Hbar"
    
    Returns: float, int, int
        m_species, A (positive), Z (can be negative)
    """
    if species == "pbar":
        return mp, 1, -1
    elif species == "Dbar":
        return mD, 2, -1
    elif species == "3Hebar":
        return m3He, 3, -2
    elif species == "3Hbar":
        return m3H, 3, -1

# %%
def toLabelStr(s):
    """
    Given a channel or final state, produces a LaTeX label for plotting
    """
    if s == "W+W-":
        return r"W^+W^-"
    elif s == "bbbar":
        return r"b\bar{b}"
    elif s == "Dbar":
        return r"\bar{D}"
    elif s == "3Hebar":
        return r"\overline{^3He}"
    elif s == "pbar":
        return r"\bar{p}"
    else:
        return ""

# %% [markdown]
# ### Load spectra

# %%
spectra = dict()

for m in masses:
    for c in channels:
        for fs in finalStates:
            if fs == "pbar":
                # No uncertainty from p_coal
                spectra[(m, c, fs)] = np.loadtxt(dataDir + "mDM_%iGeV_%s_%s.csv"%(m, c, fs), delimiter=" ")
            else:
                spectra[(m, c, fs)] = {"mean": np.loadtxt(dataDir + "mDM_%iGeV_%s_%s.csv"%(m, c, fs), delimiter=" "),
                                       "lower": np.loadtxt(dataDir + "mDM_%iGeV_%s_%s_lower.csv"%(m, c, fs), delimiter=" "),
                                       "upper": np.loadtxt(dataDir + "mDM_%iGeV_%s_%s_upper.csv"%(m, c, fs), delimiter=" ")}

# %% [markdown]
# ### Propagation effects

# %%
def get3HebarPropFn(propMethod, intMethod):
    """
    Returns an antihelium propagation function P(T), defined by
        dPhi/dT|_T = P(T) dN/dT|_T,
    where dPhi/dT is the differential flux and T is kinetic energy per nucleon.
    P(T) has units of m^-2 s^-1 sr^-1 and is defined as
        P(T) = (rhoLoc/0.39 GeV/cm^3)^2 (100 GeV/mDM)^2 (sigmaV/3e-26 cm^3/s) P_num(T),
    where P_num(T) is a function fit to the output of a numerical code.
    
    Arguments
    -propMethod: "MIN", "MED" or "MAX"
        Specifies propagation setup. TODO: see notes for details
    -intMethod: "MethodAnn" or "MethodInel"
        Specifies how antihelium interacts with cosmic rays. TODO: see notes
    
    Returns: lambda T, mDM, sigmaV=3.0e-26, rhoLoc=0.39.
        P(T). Gives 0 if unless 0.1 GeV/n < T < 50 GeV/n.
    """
    params = np.genfromtxt(dataDir + "3Hebar_prop_fits.csv", dtype=None)
    
    for p in params:
        if p[0] == propMethod and p[1] == intMethod:
            # Extract the parameters
            a0, a1, a2, a3, a4 = list(p)[2:]
            # Numerical part of the propagation function.
            ########################################################### TODO: CHANGE 60 BACK TO 50!!! #######################
            pNum = lambda T: np.exp(a0+a1*np.log(T)+a2*np.log(T)**2+a3*np.log(T)**3+a4*np.log(T)**4) * (T < 50.0) * (T > 0.1)
            
            return lambda T, mDM, sigmaV=3.0e-26, rhoLoc=0.39: (rhoLoc/0.39)**2 * (100.0/mDM)**2 * (sigmaV/3.0e-26) * pNum(T)

# %%
def getPropFn(species, propMethod):
    """
    Returns a propagation function P(T), defined by
        dPhi/dT|_T = P(T) dN/dT|_T,
    where dPhi/dT is the differential flux and T is kinetic energy per nucleon.
    P(T) has units of m^-2 s^-1 sr^-1.
    
    Arguments
    -species: "pbar" or "Dbar"
    -propMethod: "MIN", "MED" or "MAX"
        Specifies propagation setup. See notes/PPPC4DMID paper for details.
    
    Returns: T, mDM, sigmaV=3.0e-26 cm^3/s, rhoLoc=0.39 GeV/cm^-3 -> float
        P(T). Gives 0 unless 100 MeV/n < T < 100 TeV/n (for pbar), 50 MeV/n < T < 50 TeV/n (for Dbar).
    """
    if species not in ["pbar", "Dbar"]:
        print "Error: invalid particle species"
        return None
    
    mN, A, _ = nucParams(species)
    
    # Range restrictions differ for pbar and Dbar
    rangeFn = None
    if species == "pbar":
        rangeFn = lambda T: (T < 1.0e5) * (T > 0.1)
    elif species == "Dbar":
        rangeFn = lambda T: (T > 0.05) * (T < 5.0e4)

    for p in np.genfromtxt(dataDir + species + "_prop_fits.csv", dtype=None):
        if p[0] == propMethod:
            # Extract the parameters
            a0, a1, a2, a3, a4, a5 = list(p)[1:]
            
            # Numerical part of the propagation function.
            R = lambda T: 10.0**(a0 + a1*np.log10(T) + a2*np.log10(T)**2 + a3*np.log10(T)**3
                                    + a4*np.log10(T)**4 + a5*np.log10(T)) * rangeFn(T)
            
            # 1/A is present because PPPC4DMID write injection spectrum as function of total
            # kinetic energy rather than kinetic energy per nucleon. 10^4 m^2 / cm^2 and
            # c = 9.454*10^23 cm / Myr are needed to give the correct units.
            return lambda T, mDM, sigmaV=3.0e-26, rhoLoc=0.39: 1.0e4*9.454e23*np.sqrt(1.0-mN**2/(A*T+mN)**2)*rhoLoc**2*sigmaV*R(T) / (8.0*np.pi*A*mDM**2)

# %%
def solarMod(species, TIS, phiIS, phiF):
    """
    Computes flux at top of atmosphere as function of kinetic energy per
    nucleon at the top of the atmosphere.
    
    Arguments
    -TIS: float
        Energy per nucleon at boundary of solar system
    -phiIS: float
        Nucleus flux at TIS near boundary of solar system (GeV^-1)
    -species: "pbar", "Dbar", "3Hebar"
        Nucleus species
    -phiF: float
        Fisk potential (GV)
        
    Returns: float, float
        Modulated kinetic energy per nucleon TTOA (GeV/n), modulated flux 
        phiTOA (GeV^-1)
    """
    mN, A, Z = nucParams(species)
        
    # Force field approximation. Factor of e converts phiF to be in MeV
    TTOA = TIS - phiF * np.abs(Z) / float(A)
    
    return TTOA, (2*mN*A*TTOA + A**2*TTOA**2)/(2*mN*A*TIS + A**2*TIS**2) * phiIS

# %%
def propagate(species, mDM, Ts, dNdTs, sigmaV=3.0e-26, propMethod="MED", phiF=phiFVal):
    """
    Propagates injection spectrum
    
    Arguments
    -species: "pbar", "Dbar", "3Hebar"
    -mDM: float
        Dark matter mass
    -Ts: [float]
        List of kinetic energies per nucleon at production (GeV/n)
    -dNdTs: [float]
        Injection spectrum (GeV^-1)
    -sigmaV: float
        Annihilation cross section in cm^3/s
    -propMethod: "MIN", "MED", "MAX"
        Galactic propagation setting
    -phiF: float
        Fisk potential (GV)
    
    Returns: [float], [float]
        List of TOA kinetic energies per nucleon (GeV/n), list of TOA
        flux (m^-2 s^-1 sr^-1 GeV^-1)
    """
    propFn = None
    if species == "3Hebar":
        propFn = get3HebarPropFn(propMethod=propMethod, intMethod=intMethod3Hebar)
    else:
        propFn = getPropFn(propMethod=propMethod, species=species)
        
    # Apply galactic modulation
    dPhidTIS = propFn(Ts, mDM, sigmaV) * dNdTs
    
    # Apply solar propagation
    return solarMod(species, Ts, dPhidTIS, phiF)

# %% [markdown]
# ### Compute number of events expected at AMS-02

# %%
def numNucObs(mDM, species, channel, sigmaV=3.0e-26, tObs=5.0, propMethod="MED", loc="mean", Tmin=None, Tmax=None):
    """
    Arguments
    -tObs: float
        Observation time (years)
        
    Returns: float
        Expected number of Dbar observations at AMS
    """
    # Load spectrum, propagate to TOA
    spectrum = spectra[(mDM, channel, species)]
    TTOAs, dPhidTTOAs = propagate(species, mDM, spectrum[loc][:, 0], spectrum[loc][:, 1], sigmaV, propMethod)
    
    # Make sure there's overlap between the energy range and spectrum range
    if (Tmin != None and Tmin > max(TTOAs)) or (Tmax != None and Tmax < min(TTOAs)):
        return 0.0
    
    # Create interpolating function
    interpFlux = interp1d(TTOAs, dPhidTTOAs, kind="linear")
    
    # Multiply by acceptance and observation time and integrate
    acc = None
    amsGeoEff = None
    if species == "Dbar":
        acc = accDbar
        amsGeoEff = amsGeoEffDbar
    elif species == "3Hebar":
        acc = accHe
        amsGeoEff = amsGeoEff3Hebar
    else:
        print "Species not recognized"
        return 0.0
    
    # If no bounds are set, integrate over all available energies
    if Tmin == None:
        Tmin = min(TTOAs)
    if Tmax == None:
        Tmax = max(TTOAs)
    
    return quad(lambda T: tObs*3.154e7 * interpFlux(T) * acc(T) * amsGeoEff(T), Tmin, Tmax, limit=1000)[0]

# %% [markdown]
# ### Fix $\bar{^3{\rm He}}$ yield with AMS-02's data

# %%
def match3HebarYield(mDM, channel, propMethod, loc, tObs=1.0, Tmin=None, Tmax=None, alpha=None):
    """
    Finds <sigma v> such that AMS-02 observes 1 anti-helium3 nucleus per tObs with kinetic energy per nucleon between Tmin and Tmax.
    
    If alpha != None, the value of <sigma v> returned will be such that AMS-02 had a probability 1-alpha of observing 1 3Hebar in the specified energy range.
    This entails solving N(<sigma v>) exp(-N(<sigma v>)) = 1 - alpha.
    """
    #yieldFn = None
    
    #if alpha == None:
    #    yieldFn = lambda lsv: numNucObs(mDM, "3Hebar", channel, sigmaV=10.0**lsv, propMethod=propMethod, loc=loc, tObs=tObs, Tmin=Tmin, Tmax=Tmax) - 1.0
    #else:
    #    yieldHelper = lambda lsv: numNucObs(mDM, "3Hebar", channel, sigmaV=10.0**lsv, propMethod=propMethod, loc=loc, tObs=tObs, Tmin=Tmin, Tmax=Tmax)
    #    yieldFn = lambda lsv: yieldHelper(lsv) * np.exp(-yieldHelper(lsv)) - (1.0-alpha)

#    print "yieldFn: ", yieldFn(-26), yieldFn(-17)
    #return 10.0**brentq(yieldFn, -26.0, -17.0, xtol=1e-50, rtol=0.00001, maxiter=200)
    
    # Since number of nuclei \propto flux \propto <sigma v>, this is actually trivial:
    nNucRef = numNucObs(mDM, "3Hebar", channel, sigmaV=3.0e-26, propMethod=propMethod, loc=loc, tObs=tObs, Tmin=Tmin, Tmax=Tmax)
    
    if nNucRef == 0.0:
        return np.inf
    else:
        return 3.0e-26 / nNucRef

# %% [markdown]
# ### Or: maximize full likelihood function

# %%
def maxL3Hebar():
    """
    Finds values of <sigma v> that maximize the likelihood of AMS seeing 5 events in 5 years and 1 p=40 GeV event.
    
    Returns: dict
        Dictionary giving maximized probability for each channel and propagation method (with m_chi = 1000 GeV and Gamma_int method and phi_F fixed) and
        corresponding <sigma v>
    """
    n40GeV = 1.0
    n5Year = 5.0
    
    maxLResults = {}
    
    for ch, pm in list(itertools.product(["W+W-", "bbbar"], ["MIN", "MED", "MAX"])):
        # Likelihood can be maximized analytically since # nuclei \propto flux \propto <sigma v>. Result is:
        #    <sigma v> = (n_40GeV + n_5year) / (Lambda_40GeV + Lambda_5year)
        # where Lambda_i = numNucObs(sv_0, Tmin_i, Tmax_i) / sv_0, with sv_0 any reference value for <sigma v>.
        
        Lambda_5Year = numNucObs(1000.0, "3Hebar", ch, sigmaV=3.0e-26, propMethod=pm, loc="upper", tObs=5.0) / 3.0e-26
        Lambda_p40GeV = numNucObs(1000.0, "3Hebar", ch, sigmaV=3.0e-26, propMethod=pm, loc="upper", tObs=5.0, Tmin=Tmin12GeVn, Tmax=Tmax12GeVn) / 3.0e-26
        bestSV = (n40GeV + n5Year) / (Lambda_p40GeV + Lambda_5Year)
        
        # Compute corresponding probability
        lambda_5Year = bestSV * Lambda_5Year
        lambda_40GeV = bestSV * Lambda_p40GeV
        pr = lambda_40GeV**n40GeV * np.exp(-lambda_40GeV) / factorial(n40GeV) * lambda_5Year**n5Year * np.exp(-lambda_5Year) / factorial(n5Year)
        
        # Compute corresponding probability and save results
        maxLResults[(1000, ch, pm, "upper", intMethod3Hebar, phiFVal)] = (bestSV, pr)

    return maxLResults

# %% [markdown]
# #### Match to get one antihelium with $p = 40.3 \pm 2.9$ GeV/c $\leftrightarrow T \approx 12.5 \pm 1.0$ GeV/n in 5 years

# %%
#(np.sqrt(40.3**2 + m3He**2) - m3He) / float(3.0)
Tmin12GeVn = 11.56
Tmax12GeVn = 13.5

# %%
sigmaVs12GeVn = {}

for propMethod, loc, ch in list(itertools.product(["MIN", "MED", "MAX"], ["mean", "upper", "lower"], ["W+W-", "bbbar"])):
    # mDM = 100 GeV spectra drop to zero by ~10 GeV/n.
    mDM = 1000
    sigmaVs12GeVn[(mDM, ch, propMethod, loc)] = match3HebarYield(mDM, ch, propMethod, loc, tObs=5.0, Tmin=Tmin12GeVn, Tmax=Tmax12GeVn)

# %% [markdown]
# #### Match to 1 event per year

# %%
sigmaVs1yr = {}

for propMethod, loc, ch, mDM in list(itertools.product(["MIN", "MED", "MAX"], ["mean", "upper", "lower"], ["W+W-", "bbbar"], [100, 1000])):
    #print (mDM, ch, propMethod, loc)
    sigmaVs1yr[(mDM, ch, propMethod, loc)] = match3HebarYield(mDM, ch, propMethod, loc, tObs=1.0)

# %% [markdown]
# ## Can we explain $p=40$ GeV event and get 1 3Hebar / year?

# %%
for fs in ["bbbar"]:
    for pm in ["MAX"]:
        print fs, intMethod3Hebar, "phiF = %f GV"%phiFVal, pm
        sv = sigmaVs1yr[(1000, fs, pm, "upper")]
        print "<sigma v> (cm^3/s):", sv
        # Do the Poisson statisitics. This is the expected rate of 3Hebar per year over the known event's bin:
        expRate = numNucObs(1000, "3Hebar", fs, sigmaV=sv, tObs=5.0, propMethod=pm, loc="upper",
                       Tmax = Tmax12GeVn, Tmin=Tmin12GeVn)
        print "Probability of p = 40 GeV event: %f" % (expRate * np.exp(-expRate)) + "\n"
# Out:
# bbbar MethodAnn phiF = 1.500000 GV MAX
# <sigma v> (cm^3/s): 4.77754215627e-25
# Probability of p = 40 GeV event: 0.176585

# %% [markdown]
# # Final plots!

# %% [markdown]
# ### Normalized to the single $T \approx 12.5$ GeV/n antihelium observed

# %%
def plotAntinuc(mDMs, ch, pm, svDict):
    """
    Plots fluxes for the three antinucleus species.
    
    Arguments
    -mDMs: list of DM masses
    -ch: "bbbar" or "W+W-"
    -pm: propagation model
    -svDict: a dictionary with keys of the form (mDM, channel, propagationMethod, loc) that returns a value of <sigma v>
    """
    for mDM in mDMs:#, 100]:
        # Get sigmav upper and lower for these parameters
        svU = svDict[(mDM, ch, pm, "upper")]
        svL = svDict[(mDM, ch, pm, "lower")]

        # Plot pbar spectrum
        phipbar = spectra[(mDM, ch, "pbar")]
        # Get lower and upper pbar spectra
        TTOAspbarL, dPhidTTOAspbarL = propagate("pbar", mDM, phipbar[:, 0], phipbar[:, 1], svL, pm)
        TTOAspbarU, dPhidTTOAspbarU = propagate("pbar", mDM, phipbar[:, 0], phipbar[:, 1], svU, pm)
        # Fill the curves
        plt.fill(np.append(TTOAspbarL, TTOAspbarU[::-1]), np.append(dPhidTTOAspbarL, dPhidTTOAspbarU[::-1]), color=colors[mDM], alpha=0.15)

        # Plot upper and lower Dbar spectrum
        phiDbarL = spectra[(mDM, ch, "Dbar")]["upper"]
        TTOAsDbarL, dPhidTTOAsDbarL = propagate("Dbar", mDM, phiDbarL[:, 0], phiDbarL[:, 1], svL, pm)
        phiDbarU = spectra[(mDM, ch, "Dbar")]["lower"]
        TTOAsDbarU, dPhidTTOAsDbarU = propagate("Dbar", mDM, phiDbarU[:, 0], phiDbarU[:, 1], svU, pm)
        plt.fill(np.append(TTOAsDbarL, TTOAsDbarU[::-1]), np.append(dPhidTTOAsDbarL, dPhidTTOAsDbarU[::-1]), color=colors[mDM], alpha=0.4, hatch="\\\\//")

        # Plot 3Hebar spectrum
        phi3HebarL = spectra[(mDM, ch, "3Hebar")]["lower"]
        TTOAs3HebarL, dPhidTTOAs3HebarL = propagate("3Hebar", mDM, phi3HebarL[:, 0], phi3HebarL[:, 1], svL, pm)
        phi3HebarU = spectra[(mDM, ch, "3Hebar")]["upper"]
        TTOAs3HebarU, dPhidTTOAs3HebarU = propagate("3Hebar", mDM, phi3HebarU[:, 0], phi3HebarU[:, 1], svU, pm)
        plt.fill(np.append(TTOAs3HebarL, TTOAs3HebarU[::-1]), np.append(dPhidTTOAs3HebarL, dPhidTTOAs3HebarU[::-1]), color=colors[mDM], alpha=1,
                 label=r"$m_\chi = %i{\rm GeV}$"%mDM)

# %%
def commonFormatting(ch, labels=True):
    # Useful for plotting other functions
    TMin = 0.1
    TMax = 500.0
    Ts = np.logspace(np.log10(TMin), np.log10(TMax), 200)

    # AMS-02 3Hebar sensitivity (extrapolated from 18-year sensitivity to antiHe/He flux)
    #plt.plot(Ts, amsHebarSens(Ts), 'r--')

    gapsColor = "darkViolet"
    amsColor = "fuchsia"
    bessColor = "m"
    
    # Dbar upper limit
    plt.plot(bessDbarTs, 2*[bessDbarLim], color=bessColor, linewidth=2)
    
    # AMS-02 expected Dbar sensitivty
    plt.plot(amsDbarTsLow, 2*[amsDbarEstLowLim], color=amsColor, linewidth=2)
    plt.plot(amsDbarTsHigh1, 2*[amsDbarEstHigh1Lim], color=amsColor, linewidth=2)
    plt.plot(2*[amsDbarTsHigh1[1]], [amsDbarEstHigh1Lim, amsDbarEstHigh2Lim], color=amsColor, linewidth=2)
    plt.plot(amsDbarTsHigh2, 2*[amsDbarEstHigh2Lim], color=amsColor, linewidth=2)
    
    # GAPS estimated bounds
    plt.plot(gapsDbarTs, 2*[gapsDbarEstLim], color=gapsColor, linewidth=2)
    #plt.plot(gaps3HebarTs, 2*[gaps3HebarEstLim], color=gapsColor, linewidth=2)

    # AMS-02 antiproton flux
    plotBinErrs(amspbarBinl, amspbarBinr, amspbarFluxes, amspbarFluxErrs, 'r')
    
    if labels:
        #plt.text(4.8e-1, 3e-10, r"$\overline{^3{\rm He}}$ (GAPS)", fontsize=8, color=gapsColor)
        plt.text(1.2e-1, 8e-7, r"$\bar{D}$ (GAPS)", fontsize=8, color=gapsColor)
        plt.text(7e-1, 3e-6, r"$\bar{D}$ (AMS-02)", fontsize=8, color=amsColor)
        plt.text(2.4e-1, 7e-5, r"$\bar{D}$ (BESS)", fontsize=8, color=bessColor)
        plt.text(2e-1, 2.9e-2, r"$\bar{p}$ (AMS-02)", fontsize=8, color='r')

    # Label plot
    plt.title(r"$\chi\chi\to %s$"%toLabelStr(ch))
    plt.xlabel(r"Kinetic energy per nucleon, T (GeV/n)")
    plt.ylabel(r"$\Phi\ ({\rm m}^2\ {\rm s}\ {\rm sr}\ {\rm GeV}/n)^{-1} $")

    # Fix axes
    plt.xscale("log")
    plt.yscale("log")
    plt.xlim(TMin, TMax)
    plt.ylim(1e-10, 1)

# %%
plt.figure(figsize=(10, 4))

pm = "MIN"

plt.subplot(1, 2, 1)
plotAntinuc([1000], "W+W-", pm, sigmaVs12GeVn)

# Label species
plt.text(3e1, 6e-3, r"$\bar{p}$", fontsize=10, color=colors[1000])
plt.text(3e1, 9e-7, r"$\bar{D}$", fontsize=10, color=colors[1000])
plt.text(3e1, 1e-9, r"$\overline{^3{\rm He}}$", fontsize=10, color=colors[1000])

commonFormatting("W+W-")

#plt.title(r"0.2 $R\sim 12\ {\rm GV}\ \overline{^3{\rm He}}\ {\rm yr}^{-1},\ \chi\chi \to W^+ W^-$")

#############

plt.subplot(1, 2, 2)
plotAntinuc([1000], "bbbar", pm, sigmaVs12GeVn)
# Label species
plt.text(3e1, 3e-2, r"$\bar{p}$", fontsize=10, color=colors[1000])
plt.text(3e1, 7e-6, r"$\bar{D}$", fontsize=10, color=colors[1000])
plt.text(7e0, 1.3e-9, r"$\overline{^3{\rm He}}$", fontsize=10, color=colors[1000])
commonFormatting("bbbar")

#plt.title(r"0.2 $R\sim 12\ {\rm GV}\ \overline{^3{\rm He}}\ {\rm yr}^{-1},\ \chi\chi \to b\bar{b}$")

plt.legend(loc="upper right")

plt.savefig("../../Shared_antihelium3/Figures/%s_phiF%iMV_%s/40GeV_5year.pdf"%(intMethod3Hebar.lower(), 1000*phiFVal, pm))

# %%
plt.figure(figsize=(10, 4))

pm = "MAX"

plt.subplot(1, 2, 1)
plotAntinuc([100, 1000], "W+W-", pm, sigmaVs1yr)

# Label species
plt.text(2.6e1, 1.8e-5, r"$\bar{p}$", fontsize=10, color=colors[100])
plt.text(6.3e0, 4.5e-6, r"$\bar{D}$", fontsize=10, color=colors[100])
plt.text(4e0, 8e-9, r"$\overline{^3{\rm He}}$", fontsize=10, color=colors[100])

plt.text(2e2, 4e-5, r"$\bar{p}$", fontsize=10, color=colors[1000])
plt.text(2e2, 9e-10, r"$\bar{D}$", fontsize=10, color=colors[1000])
plt.text(3.5e1, 2e-10, r"$\overline{^3{\rm He}}$", fontsize=10, color=colors[1000])

commonFormatting("W+W-")

#plt.title(r"1 $\overline{^3{\rm He}}\ {\rm yr}^{-1},\ \chi\chi \to W^+ W^-$")

#############

plt.subplot(1, 2, 2)
plotAntinuc([100, 1000], "bbbar", pm, sigmaVs1yr)

# Label species
plt.text(5.5e0, 2.4e-1, r"$\bar{p}$", fontsize=10, color=colors[100])
plt.text(5.2e0, 6e-5, r"$\bar{D}$", fontsize=10, color=colors[100])
plt.text(3.5e0, 3e-10, r"$\overline{^3{\rm He}}$", fontsize=10, color=colors[100])

plt.text(1.7e2, 4e-5, r"$\bar{p}$", fontsize=10, color=colors[1000])
plt.text(2e2, 2.4e-10, r"$\bar{D}$", fontsize=10, color=colors[1000])
plt.text(4e-1, 5e-9, r"$\overline{^3{\rm He}}$", fontsize=10, color=colors[1000])

commonFormatting("bbbar")

#plt.title(r"1 $\overline{^3{\rm He}}\ {\rm yr}^{-1},\ \chi\chi \to b\bar{b}$")

plt.legend(loc="upper right")

plt.savefig("../../Shared_antihelium3/Figures/%s_phiF%iMV_%s/1peryear.pdf"%(intMethod3Hebar.lower(), 1000*phiFVal, pm))

# %%
plt.figure(figsize=(5, 4))

#plt.subplot(1, 2, 1)

#plotAntinuc([1000], "bbbar", "MAX", sigmaVs12GeVn)
# Label species
#plt.text(3e1, 5e-2, r"$\bar{p}$", fontsize=10, color=colors[1000])
#plt.text(3e1, 1e-5, r"$\bar{D}$", fontsize=10, color=colors[1000])
#plt.text(7e0, 7e-10, r"$\overline{^3{\rm He}}$", fontsize=10, color=colors[1000])
#commonFormatting("bbbar")

# Zoom in on interesting part
#plt.subplot(1, 2, 2)

plotAntinuc([1000], "bbbar", "MAX", sigmaVs12GeVn)
commonFormatting("bbbar", False)

#plt.title(r"1 $R\sim 12\ {\rm GV}\ \overline{^3{\rm He}}\ {\rm yr}^{-1},\ \chi\chi \to b\bar{b}$")

plt.xlim(2e1, 1e2)
plt.ylim(1e-5, 1e-3)

plt.savefig("../../Shared_antihelium3/Figures/1_12GeVn_5year_" + intMethod3Hebar.lower() + "_zoom.pdf")

# %% [markdown]
# ### Normalized to one antihelium per year

# %%
plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plotAntinuc([1000], "W+W-", "MAX", sigmaVs1yr)

# Label species
plt.text(2e2, 5e-5, r"$\bar{p}$", fontsize=10, color=colors[1000])
plt.text(2e2, 1.2e-9, r"$\bar{D}$", fontsize=10, color=colors[1000])
plt.text(3.5e1, 3e-10, r"$\overline{^3{\rm He}}$", fontsize=10, color=colors[1000])

commonFormatting("W+W-")

#############

plt.subplot(1, 2, 2)
plotAntinuc([1000], "bbbar", "MAX", sigmaVs1yr)

# Label species
plt.text(1e2, 3e-4, r"$\bar{p}$", fontsize=10, color=colors[1000])
plt.text(1.9e2, 2.3e-10, r"$\bar{D}$", fontsize=10, color=colors[1000])
plt.text(2e-1, 1.9e-9, r"$\overline{^3{\rm He}}$", fontsize=10, color=colors[1000])

commonFormatting("bbbar")

plt.legend(loc="upper right")

plt.savefig("../../Shared_antihelium3/Figures/%s_phiF%iMV_%s/1peryear_1000GeV.pdf"%(intMethod3Hebar.lower(), 1000*phiFVal, pm))

# %%
plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plotAntinuc([100], "W+W-", "MAX", sigmaVs1yr)

# Label species
plt.text(2e1, 2e-5, r"$\bar{p}$", fontsize=10, color=colors[100])
plt.text(3e0, 8e-6, r"$\bar{D}$", fontsize=10, color=colors[100])
plt.text(2.8e0, 5e-9, r"$\overline{^3{\rm He}}$", fontsize=10, color=colors[100])

commonFormatting("W+W-")

#############

plt.subplot(1, 2, 2)
plotAntinuc([100], "bbbar", "MAX", sigmaVs1yr)

# Label species
plt.text(3e0, 2.8e-1, r"$\bar{p}$", fontsize=10, color=colors[100])
plt.text(3e0, 7e-5, r"$\bar{D}$", fontsize=10, color=colors[100])
plt.text(3e0, 3e-10, r"$\overline{^3{\rm He}}$", fontsize=10, color=colors[100])

commonFormatting("bbbar")

plt.legend(loc="upper right")

plt.savefig("../../Shared_antihelium3/Figures/%s_phiF%iMV_%s/1peryear_100GeV.pdf"%(intMethod3Hebar.lower(), 1000*phiFVal, pm))

# %%
numNucObs(1000, "3Hebar", "W+W-", sigmaV=sigmaVs12GeVn[(1000, "W+W-", "MAX", "lower")], tObs=5.0, propMethod="MAX", loc="lower")
# Out:
# 11.786627585090475

# %%
print numNucObs(1000, "3Hebar", "bbbar", sigmaV=sigmaVs12GeVn[(1000, "bbbar", "MAX", "lower")], tObs=5.0, propMethod="MAX", loc="lower")
print numNucObs(1000, "3Hebar", "bbbar", sigmaV=sigmaVs12GeVn[(1000, "bbbar", "MAX", "upper")], tObs=5.0, propMethod="MAX", loc="upper")
# Out:
# 31.6252792667
# 34.2899682386

# %%
sigmaVs12GeVn[(1000, "bbbar", "MAX", "upper")]
# Out:
# 1.7720927914244312e-24

# %%
sigmaVs1yr[(1000, "bbbar", "MAX", "upper")]
# Out:
# 2.023178628805974e-26

# %% [markdown]
# Print expected number of $p=40$ GeV 3Hebars in 5 years and sigma v

# %%
sigmaVs1yr[(1000, "bbbar", pm, "upper")]
# Out:
# 2.5837507818683206e-25

# %% [markdown]
# # Plot of acceptances

# %%
testTs = np.logspace(-1, 3, 100)

plt.plot([1e-1, 1e3], [0.5, 0.5], 'r-', label="Geom.", linewidth=2)

plt.plot(testTs, accHe(testTs), '--', label=r"$\bar{^3{\rm He}}$ (est.)")
plt.plot(testTs, accDbarEst(testTs), '--', label=r"$\bar{D}$ (est.)")
plt.plot(testTs, accpbarEst(testTs), '--', label=r"$\bar{p}$ (est.)")

plt.plot(testTs, accDbar(testTs), label=r"$\bar{D}$")
plt.plot(testTs, accpbar(testTs), label=r"$\bar{p}$")

plt.xscale("log")
plt.yscale("log")
plt.xlabel(r"$T$ (GeV/n)")
plt.ylabel(r"Acceptance (${\rm m}^2\ {\rm sr}^2$)")
plt.legend(loc="lower right")

# %% [markdown]
# Plot TOA spectra

# %%
propMethod = "MAX"
channel = "bbbar"
sigmaV = sigmaVs12GeVn[(1000, 'bbbar', 'MAX', 'upper')]

for k, spectrum in spectra.iteritems():
    mDM, c, fs = k
    
    if c == channel and mDM == 1000:
        
        if fs == "pbar":
            TTOAs, dPhidTTOAs = propagate(fs, mDM, spectrum[:, 0], spectrum[:, 1], sigmaV, propMethod)
            plt.plot(TTOAs, dPhidTTOAs, lines[fs], color=colors[mDM], linewidth=0.5)
        else:
            for loc in ["upper", "lower", "mean"]:
                TTOAs, dPhidTTOAs = propagate(fs, mDM, spectrum[loc][:, 0], spectrum[loc][:, 1], sigmaV, propMethod)
                plt.plot(TTOAs, dPhidTTOAs, lines[fs], color=colors[mDM], linewidth=0.5)
        
plt.xscale("log")
plt.yscale("log")
plt.title(r"TOA spectra, $\chi\chi\to %s$" % toLabelStr(channel))
#plt.legend(loc="upper right")
plt.xlabel(r"Kinetic energy per nucleon, T (GeV/n)")
plt.ylabel(r"$Phi\ ({\rm s}^{-1} {\rm m}^{-2} {\rm sr}^{-1} {\rm GeV}^{-1})$")
plt.xlim(0.1, 500)
# Out:
# (0.1, 500)

# %%
channel = "bbbar"

for k, spectrum in spectra.iteritems():
    mDM, c, fs = k
    
    if c == channel:
        # Style things
        color = colors[mDM]
        styleStr = color + lines[fs]
        
        if fs == "pbar":
            plt.plot(spectrum[:, 0], spectrum[:, 1], styleStr, linewidth=0.5, label=r"$m_\chi = %i$ GeV" % mDM)
        else:
            plt.plot(spectrum["mean"][:, 0], spectrum["mean"][:, 1], styleStr, linewidth=0.5)

            # Fill between upper and lower bounds
            plt.fill(np.append(spectrum["lower"][:, 0], spectrum["mean"][::-1, 0]),
                     np.append(spectrum["lower"][:, 1], spectrum["mean"][::-1, 1]), color=color, alpha=0.3, linewidth=0)
            
            plt.fill(np.append(spectrum["mean"][:, 0], spectrum["upper"][::-1, 0]),
                     np.append(spectrum["mean"][:, 1], spectrum["upper"][::-1, 1]), color=color, alpha=0.3, linewidth=0)
    
plt.xscale("log")
plt.yscale("log")
plt.title(r"$\chi\chi\to %s$" % toLabelStr(channel))
plt.legend(loc="upper right")
plt.xlabel(r"Kinetic energy per nucleon, T (GeV/n)")
plt.ylabel(r"$dN/dT\ ({\rm GeV}^{-1})$")
plt.xlim(1e-2, 1e3)
plt.ylim(1e-10, 1)
# Out:
# (1e-10, 1)

# %% [markdown]
# ## Fisk potential $\phi_F$ (from http://cosmicrays.oulu.fi/phi/Phi_mon.txt)

# %%
phiFs = [279, 528, 481, 438, 291, 316, 279, 279, 212, 261, 543, 788, 647, 568, 506, 562, 497, 488, 404, 420, 593, 1068, 1172, 
         1095, 1028, 795, 693, 579, 451, 382, 499, 643, 770, 852, 818, 553, 491, 481, 520, 442, 424, 436, 544, 739, 845, 
         969, 1046, 874, 797, 564, 434, 414, 658, 1161, 1226, 1234, 785, 588, 546, 467, 428, 412, 500, 629, 944, 860, 936, 954, 
         677, 641, 440, 361, 334, 271, 364, 478, 565, 603, 645, 644, 444]

plt.plot(phiFs, '.')

# %% [markdown]
# ### Never need to use this

# %%
def numpbarObs(mDM, channel, sigmaV=3.0e-26, tObs=5.0, propMethod="MED", Tmin=None, Tmax=None):
    """
    Arguments
    -tObs: float
        Observation time (years)
        
    Returns: float
        Expected number of Dbar observations at AMS
    """
    # Load spectrum, propagate to TOA
    spectrum = spectra[(mDM, channel, "pbar")]
    TTOAs, dPhidTTOAs = propagate("pbar", mDM, spectrum[:, 0], spectrum[:, 1], sigmaV, propMethod)
    
    # Create interpolating function
    interpFlux = interp1d(TTOAs, dPhidTTOAs, kind="linear")
    
    # If no bounds are set, integrate over all available energies
    if Tmin == None:
        Tmin = min(TTOAs)
    if Tmax == None:
        Tmax = max(TTOAs)
    
    # Multiply by acceptance and integrate
    return quad(lambda T: tObs*3.154e7 * interpFlux(T) * accpbar(T) * amsGeoEffpbar(T), Tmin, Tmax, limit=500)[0]
